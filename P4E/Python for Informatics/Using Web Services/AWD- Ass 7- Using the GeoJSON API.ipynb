# %%
import urllib.request, urllib.parse, urllib.error
import json

# Note that Google is increasingly requiring keys
# for this API
serviceurl = 'http://py4e-data.dr-chuck.net/geojson?'

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    url = serviceurl + urllib.parse.urlencode(
        {'address': address},{'sensor': 'false'})

    print('Retrieving', url)
    uh = urllib.request.urlopen(url)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    #print(data)
    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        #print(data)
        continue

    print(json.dumps(js, indent=4))
    print(js["results"][0]["place_id"])
# Out:
# Enter location: Missouri University of Science and Technology
# Retrieving http://py4e-data.dr-chuck.net/geojson?address=Missouri+University+of+Science+and+Technology
# Retrieved 2223 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "short_name": "Beijing University of Technology the Science Building",
#                     "types": [
#                         "premise"
#                     ],
#                     "long_name": "Beijing University of Technology the Science Building"
#                 },
#                 {
#                     "short_name": "Chaoyang",
#                     "types": [
#                         "sublocality_level_1",
#                         "sublocality",
#                         "political"
#                     ],
#                     "long_name": "Chaoyang"
#                 },
#                 {
#                     "short_name": "Beijing",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "long_name": "Beijing"
#                 },
#                 {
#                     "short_name": "Beijing",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "long_name": "Beijing"
#                 },
#                 {
#                     "short_name": "CN",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "long_name": "China"
#                 },
#                 {
#                     "short_name": "100124",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "long_name": "100124"
#                 }
#             ],
#             "partial_match": true,
#             "formatted_address": "Beijing University of Technology the Science Building, Chaoyang, Beijing, China, 100124",
#             "geometry": {
#                 "viewport": {
#                     "southwest": {
#                         "lng": 116.4783272697085,
#                         "lat": 39.8716302197085
#                     },
#                     "northeast": {
#                         "lng": 116.4810252302915,
#                         "lat": 39.8743281802915
#                     }
#                 },
#                 "location_type": "ROOFTOP",
#                 "location": {
#                     "lng": 116.4796427,
#                     "lat": 39.8729896
#                 },
#                 "bounds": {
#                     "southwest": {
#                         "lng": 116.4791784,
#                         "lat": 39.8728907
#                     },
#                     "northeast": {
#                         "lng": 116.4801741,
#                         "lat": 39.8730677
#                     }
#                 }
#             },
#             "types": [
#                 "premise"
#             ],
#             "place_id": "ChIJ5bJYioit8TURnkX3kVIepYg"
#         }
#     ],
#     "status": "OK"
# }
# ChIJ5bJYioit8TURnkX3kVIepYg
